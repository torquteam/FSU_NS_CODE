# %%
# (Run First) Import prior and packages
import matplotlib.pyplot as plt
import numpy as np
import statistics
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf
import seaborn as sns
PostAX = np.loadtxt("postAstroXEFTnm.txt")
PostAX2 = np.loadtxt("postXEFT_FSUGOLD.txt")

# %%
# Get averages and std deviations

start = 0
print('PostAX: ')
print('BA = ' + str(statistics.mean(PostAX[start:,0])) + ' +/- ' + str(statistics.stdev(PostAX[start:,0])))
print('kf = ' + str(statistics.mean(PostAX[start:,1])) + ' +/- ' + str(statistics.stdev(PostAX[start:,1])))
print('mstar = ' + str(statistics.mean(PostAX[start:,2])) + ' +/- ' + str(statistics.stdev(PostAX[start:,2])))
print('K = ' + str(statistics.mean(PostAX[start:,3])) + ' +/- ' + str(statistics.stdev(PostAX[start:,3])))
print('J = ' + str(statistics.mean(PostAX[start:,4])) + ' +/- ' + str(statistics.stdev(PostAX[start:,4])))
print('L = ' + str(statistics.mean(PostAX[start:,5])) + ' +/- ' + str(statistics.stdev(PostAX[start:,5])))
print('h = ' + str(statistics.mean(PostAX[start:,6])) + ' +/- ' + str(statistics.stdev(PostAX[start:,6])))
print('R1.4 = ' + str(statistics.mean(PostAX[start:,11])) + ' +/- ' + str(statistics.stdev(PostAX[start:,11])))
print('R2.08 = ' + str(statistics.mean(PostAX[start:,8])) + ' +/- ' + str(statistics.stdev(PostAX[start:,8])))
print('TD1.4 = ' + str(statistics.mean(PostAX[start:,12])) + ' +/- ' + str(statistics.stdev(PostAX[start:,12])))
print('Mmax = ' + str(statistics.mean(PostAX[start:,13])) + ' +/- ' + str(statistics.stdev(PostAX[start:,13])))

print('PostXEFT2: ')
print('BA = ' + str(statistics.mean(PostAX2[start:,0])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,0])))
print('kf = ' + str(statistics.mean(PostAX2[start:,1])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,1])))
print('mstar = ' + str(statistics.mean(PostAX2[start:,2])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,2])))
print('K* = ' + str(statistics.mean(PostAX2[start:,3])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,3])))
print('J = ' + str(statistics.mean(PostAX2[start:,4])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,4])))
print('L = ' + str(statistics.mean(PostAX2[start:,5])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,5])))
print('h = ' + str(statistics.mean(PostAX2[start:,6])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,6])))
print('R1.4 = ' + str(statistics.mean(PostAX2[start:,11])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,11])))
print('R2.08 = ' + str(statistics.mean(PostAX2[start:,8])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,8])))
print('TD1.4 = ' + str(statistics.mean(PostAX2[start:,12])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,12])))
print('Mmax = ' + str(statistics.mean(PostAX2[start:,13])) + ' +/- ' + str(statistics.stdev(PostAX2[start:,13])))
# Out:
# PostAX:
# BA = -16.2171173482155 +/- 0.01886155503631546
# kf = 1.3108884211548 +/- 0.0014879203051700793
# mstar = 0.59374733482189 +/- 0.0034201285366000055
# K = 241.219472970715 +/- 2.4404541935939488
# J = 31.9755904798305 +/- 0.24133244561793293
# L = 57.112515534535 +/- 0.9788901283091951
# h = 0.00200072735376541 +/- 0.0003030894979369859
# R1.4 = 13.2746483690025 +/- 0.04346368234090858
# R2.08 = 12.9775731393575 +/- 0.13678418546017945
# TD1.4 = 731.79114366164 +/- 20.506001507583747
# Mmax = 2.25724437344515 +/- 0.04123407893112725
# PostXEFT2:
# BA = -16.220544793532 +/- 0.018743836374186848
# kf = 1.3111414126696 +/- 0.0014602266066545638
# mstar = 0.59395222316586 +/- 0.0034272053124752492
# K* = 241.18466888182 +/- 2.4882460331875826
# J = 32.02624212857 +/- 0.23898719020478185
# L = 57.198493299681 +/- 0.9846898924795128
# h = 0.00194329706865254 +/- 0.00030414131675287346
# R1.4 = 13.278610321922 +/- 0.044456074586921995
# ...

# %%
# Histograms of parameters
nbins = 50
start = 0
fig, axs = plt.subplots(3, 7,figsize=(30,10))
axs[0,0].hist(prior[start:,0], bins = nbins,density=True)
axs[0,1].hist(prior[start:,1], bins = nbins,density=True)
axs[0,2].hist(prior[start:,2], bins = nbins,density=True)
axs[0,3].hist(prior[start:,3], bins = nbins,density=True)
axs[0,4].hist(prior[start:,4], bins = nbins,density=True)
axs[0,5].hist(prior[start:,5], bins = nbins,density=True)
axs[0,6].hist(prior[start:,6], bins = nbins,density=True)
axs[1,0].hist(postA[start:,0], bins = nbins,density=True)
axs[1,1].hist(postA[start:,1], bins = nbins,density=True)
axs[1,2].hist(postA[start:,2], bins = nbins,density=True)
axs[1,3].hist(postA[start:,3], bins = nbins,density=True)
axs[1,4].hist(postA[start:,4], bins = nbins,density=True)
axs[1,5].hist(postA[start:,5], bins = nbins,density=True)
axs[1,6].hist(postA[start:,6], bins = nbins,density=True)
axs[2,0].hist(postAX[start:,0], bins = nbins,density=True)
axs[2,1].hist(postAX[start:,1], bins = nbins,density=True)
axs[2,2].hist(postAX[start:,2], bins = nbins,density=True)
axs[2,3].hist(postAX[start:,3], bins = nbins,density=True)
axs[2,4].hist(postAX[start:,4], bins = nbins,density=True)
axs[2,5].hist(postAX[start:,5], bins = nbins,density=True)
axs[2,6].hist(postAX[start:,6], bins = nbins,density=True)

axs[0,0].set_title('BA')
axs[0,1].set_title('kf')
axs[0,2].set_title('mstar')
axs[0,3].set_title('K')
axs[0,4].set_title('J')
axs[0,5].set_title('L')
axs[0,6].set_title('h')

axs[0,0].set(xlabel='', ylabel='prior')
axs[1,0].set(xlabel='', ylabel='postAstro')
axs[2,0].set(xlabel='', ylabel='postAstro+XEFT')

plt.savefig("CompareBulks_soft_nomax.png",transparent=False,facecolor='white')

# %%
nbins = 50
start = 0
fig, axs = plt.subplots(3, 4,figsize=(20,10))
axs[0,0].hist(prior[start:,11], bins = nbins,density=True)
axs[0,1].hist(prior[start:,8], bins = nbins,density=True)
axs[0,2].hist(prior[start:,12], bins = nbins,density=True)
axs[0,3].hist(prior[start:,13], bins = nbins,density=True)
axs[1,0].hist(postA[start:,11], bins = nbins,density=True)
axs[1,1].hist(postA[start:,8], bins = nbins,density=True)
axs[1,2].hist(postA[start:,12], bins = nbins,density=True)
axs[1,3].hist(postA[start:,13], bins = nbins,density=True)
axs[2,0].hist(postAX[start:,11], bins = nbins,density=True)
axs[2,1].hist(postAX[start:,8], bins = nbins,density=True)
axs[2,2].hist(postAX[start:,12], bins = nbins,density=True)
axs[2,3].hist(postAX[start:,13], bins = nbins,density=True)

axs[0,0].set_title('$R_{1.4}$ (km)')
axs[0,1].set_title('$R_{2.08}$ (km)')
axs[0,2].set_title(r'$\tilde{\Lambda}_{1.4}$')
axs[0,3].set_title('$M_{max}$')

axs[0,0].set(xlabel='', ylabel='prior')
axs[1,0].set(xlabel='', ylabel='postAstro')
axs[2,0].set(xlabel='', ylabel='postAstro+XEFT')

plt.savefig("CompareObservables_soft_nomax.png",transparent=False,facecolor='white')

# %%
# Time series of monte carlo steps
width = 1.0
start = 0
fig, axs = plt.subplots(1, 4,figsize=(20,5))
axs[0].plot(postA[start:,5],linewidth=width)
axs[1].plot(postA[start:,6],linewidth=width)
axs[2].plot(postA[start:,7],linewidth=width)
axs[3].plot(postA[start:,14],linewidth=width)
axs[0].set_title('$R_{1.46}$')
axs[1].set_title(r'$\tilde{\Lambda}_{1.46}$')
axs[2].set_title('$R_{max}$')
axs[3].set_title('$M_{max}$')
# Out:
# Text(0.5, 1.0, '$M_{max}$')

# %%
# Scatter Covariance Plots
fig, axs = plt.subplots(11, 11,figsize=(60,60))
start=0

sy = 0
data = postAX
for i in range(15):
    sx = 0
    if (i==10 or i==7 or i==9 or i==14):
        sy = sy+1
        continue
    for j in range(15):
        if (i==j): 
            continue
        if (j==10 or j==7 or j==9 or j==14):
            sx = sx+1
            continue
        if (i<j):
            axs[i-sy,j-sx].axis('off')
        else:
            axs[i-sy,j-sx].scatter(data[start:,i],data[start:,j],s=1)


axs[0, 0].hist(data[start:,0], bins = 100)
axs[1, 1].hist(data[start:,1], bins = 100)
axs[2, 2].hist(data[start:,2], bins = 100)
axs[3, 3].hist(data[start:,3], bins = 100)
axs[4, 4].hist(data[start:,4], bins = 100)
axs[5, 5].hist(data[start:,5], bins = 100)
axs[6, 6].hist(data[start:,6], bins = 100)
axs[7, 7].hist(data[start:,8], bins = 100)
axs[8, 8].hist(data[start:,11], bins = 100)
axs[9, 9].hist(data[start:,12], bins = 100)
axs[10, 10].hist(data[start:,13], bins = 100)

axs[0, 0].set_title('BA')
axs[1, 1].set_title('kf')
axs[2, 2].set_title('m*')
axs[3, 3].set_title('K')
axs[4, 4].set_title('J')
axs[5, 5].set_title('L')
axs[6, 6].set_title('h')
axs[7, 7].set_title('R2.08')
axs[8, 8].set_title('R1.4')
axs[9, 9].set_title('TD1.4')
axs[10, 10].set_title('Mmax')


axs[0,0].set(xlabel='', ylabel='BA')
axs[1,0].set(xlabel='', ylabel='kf')
axs[2,0].set(xlabel='', ylabel='m*')
axs[3,0].set(xlabel='', ylabel='K')
axs[4,0].set(xlabel='', ylabel='J')
axs[5,0].set(xlabel='', ylabel='L')
axs[6,0].set(xlabel='', ylabel='Zeta')
axs[7,0].set(xlabel='', ylabel='R2.08')
axs[8,0].set(xlabel='', ylabel='R1.4')
axs[9,0].set(xlabel='', ylabel='TD1.4')
axs[10,0].set(xlabel='', ylabel='Mmax')

axs[0,0].set_xticks(axs[0,0].get_xticks()[::2])

for j in range(7):
    axs[6,j].set_xticks(axs[6,j].get_xticks()[::2])


plt.savefig("cov_stiff.png",transparent=False,facecolor='white')

# %%
#Get covariance matrix from data
import numpy as np
postA = np.loadtxt("postAstro0829.txt")
conv = np.loadtxt("startfileAstro.txt")
postA[:,0] = postA[:,0]/conv[0,3]
postA[:,1] = postA[:,1]/conv[1,3]
postA[:,2] = postA[:,2]/conv[2,3]
postA[:,3] = postA[:,3]/conv[3,3]
postA[:,4] = postA[:,4]/conv[4,3]
postA[:,5] = postA[:,5]/conv[5,3]
postA[:,6] = postA[:,6]/conv[6,3]
data = postA[:,0:7]
data = np.transpose(data)
covmat = np.cov(data)
invcov = np.linalg.inv(covmat)
print(invcov)
np.savetxt("invcovPOSTERIOR.txt",invcov, delimiter ="  ")
# Out:
# [[ 3.70767250e+06 -1.93256362e+06 -3.93913784e+05 -1.60064513e+05
#   -2.77555394e+05  3.06707110e+04 -1.98411672e+04]
#  [-1.93256362e+06  2.65613939e+06  1.37803840e+05  1.70848122e+05
#    1.12091242e+05 -1.14874840e+04  4.05948978e+04]
#  [-3.93913784e+05  1.37803840e+05  7.29418424e+04  1.48044456e+04
#    3.43283697e+04 -4.43292517e+03  1.93193816e+03]
#  [-1.60064513e+05  1.70848122e+05  1.48044456e+04  2.08798041e+04
#    1.07156611e+04 -1.08666128e+03  2.91100786e+03]
#  [-2.77555394e+05  1.12091242e+05  3.43283697e+04  1.07156611e+04
#    3.64791043e+04 -4.55149540e+03  1.79984634e+03]
#  [ 3.06707110e+04 -1.14874840e+04 -4.43292517e+03 -1.08666128e+03
#   -4.55149540e+03  7.12386258e+02 -5.73144700e+02]
#  [-1.98411672e+04  4.05948978e+04  1.93193816e+03  2.91100786e+03
#    1.79984634e+03 -5.73144700e+02  2.02662468e+03]]

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt("CORRMATRIXTEST.txt")
data = np.transpose(data)

b=54
n=54
tot=b+n
xb = np.linspace(0.7,6.0,b)
xn = np.linspace(0.7,6.0,n)

fig, axs = plt.subplots(5, 4,figsize=(20,15))
axs[0, 0].plot(xb,data[0:b,1])
axs[0, 1].plot(xb,data[0:b,2])
axs[1, 0].plot(xb,data[0:b,3])
axs[1, 1].plot(xb,data[0:b,4])
axs[2, 0].plot(xb,data[0:b,5],xb,data[0:b,0])
axs[2, 1].plot(xb,data[0:b,6])
axs[3, 0].plot(xb,data[0:b,7])
axs[3, 1].plot(xb,data[0:b,8])
axs[4, 0].plot(xb,data[0:b,9])
axs[4, 1].plot(xb,data[0:b,10])
axs[0, 2].plot(xn,data[b:tot,1])
axs[0, 3].plot(xn,data[b:tot,2])
axs[1, 2].plot(xn,data[b:tot,3])
axs[1, 3].plot(xn,data[b:tot,4])
axs[2, 2].plot(xn,data[b:tot,5],xn,data[b:tot,0])
axs[2, 3].plot(xn,data[b:tot,6])
axs[3, 2].plot(xn,data[b:tot,7])
axs[3, 3].plot(xn,data[b:tot,8])
axs[4, 2].plot(xn,data[b:tot,9])
axs[4, 3].plot(xn,data[b:tot,10])

axs[0,0].set_xlim([0.7, 4])
axs[0,1].set_xlim([0.7, 4])
axs[1,0].set_xlim([0.7, 4])
axs[1,1].set_xlim([0.7, 4])
axs[2,0].set_xlim([0.7, 4])
axs[2,1].set_xlim([0.7, 4])
axs[3,0].set_xlim([0.7, 4])
axs[3,1].set_xlim([0.7, 4])
axs[4,0].set_xlim([0.7, 4])
axs[4,1].set_xlim([0.7, 4])

ll = 0.5
ul = 6
axs[0,2].set_xlim([ll, ul])
axs[0,3].set_xlim([ll, ul])
axs[1,2].set_xlim([ll, ul])
axs[1,3].set_xlim([ll, ul])
axs[2,2].set_xlim([ll, ul])
axs[2,3].set_xlim([ll, ul])
axs[3,2].set_xlim([ll, ul])
axs[3,3].set_xlim([ll, ul])
axs[4,2].set_xlim([ll, ul])
axs[4,3].set_xlim([ll, ul])

axs[0, 0].set_title('R1.0')
axs[0, 1].set_title('R1.1')
axs[1, 0].set_title('R1.2')
axs[1, 1].set_title('R1.3')
axs[2, 0].set_title('TD1.4 and R1.4')
axs[2, 1].set_title('R1.5')
axs[3, 0].set_title('R1.6')
axs[3, 1].set_title('R1.7')
axs[4, 0].set_title('R1.8')
axs[4, 1].set_title('R1.9')
axs[0, 2].set_title('R1.0')
axs[0, 3].set_title('R1.1')
axs[1, 2].set_title('R1.2')
axs[1, 3].set_title('R1.3')
axs[2, 2].set_title('TD1.4 and R1.4')
axs[2, 3].set_title('R1.5')
axs[3, 2].set_title('R1.6')
axs[3, 3].set_title('R1.7')
axs[4, 2].set_title('R1.8')
axs[4, 3].set_title('R1.9')
plt.tight_layout()
plt.savefig("corr_stiff_astroXEFT.png",transparent=False,facecolor='white')

# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.loadtxt("CORRMATRIX_soft_XEFT_dens.txt")
data1 = np.transpose(data1)
data2 = np.loadtxt("CORRMATRIX_stiff_XEFT_dens.txt")
data2 = np.transpose(data2)

b=54
n=54
tot=b+n
xb = np.linspace(0.7,6.0,b)
xn = np.linspace(0.7,6.0,n)

fig, axs = plt.subplots(5, 4,figsize=(20,15))
axs[0, 0].plot(xb,data1[0:b,1],linestyle='dashed',color='royalblue')
axs[0, 0].plot(xb,data2[0:b,1],color='royalblue')
axs[0, 1].plot(xb,data1[0:b,2],linestyle='dashed',color='royalblue')
axs[0, 1].plot(xb,data2[0:b,2],color='royalblue')
axs[1, 0].plot(xb,data1[0:b,3],linestyle='dashed',color='royalblue')
axs[1, 0].plot(xb,data2[0:b,3],color='royalblue')
axs[1, 1].plot(xb,data1[0:b,4],linestyle='dashed',color='royalblue')
axs[1, 1].plot(xb,data2[0:b,4],color='royalblue')
axs[2, 0].plot(xb,data1[0:b,5],linestyle='dashed',color='royalblue')
axs[2, 0].plot(xb,data1[0:b,0],linestyle='dashed',color='red')
axs[2, 0].plot(xb,data2[0:b,5],color='royalblue')
axs[2, 0].plot(xb,data2[0:b,0],color='red')
axs[2, 1].plot(xb,data1[0:b,6],linestyle='dashed',color='royalblue')
axs[2, 1].plot(xb,data2[0:b,6],color='royalblue')
axs[3, 0].plot(xb,data1[0:b,7],linestyle='dashed',color='royalblue')
axs[3, 0].plot(xb,data2[0:b,7],color='royalblue')
axs[3, 1].plot(xb,data1[0:b,8],linestyle='dashed',color='royalblue')
axs[3, 1].plot(xb,data2[0:b,8],color='royalblue')
axs[4, 0].plot(xb,data1[0:b,9],linestyle='dashed',color='royalblue')
axs[4, 0].plot(xb,data2[0:b,9],color='royalblue')
axs[4, 1].plot(xb,data1[0:b,10],linestyle='dashed',color='royalblue')
axs[4, 1].plot(xb,data2[0:b,10],color='royalblue')


axs[0, 2].plot(xn,data1[b:tot,1],linestyle='dashed',color='royalblue')
axs[0, 2].plot(xn,data2[b:tot,1],color='royalblue')
axs[0, 3].plot(xn,data1[b:tot,2],linestyle='dashed',color='royalblue')
axs[0, 3].plot(xn,data2[b:tot,2],color='royalblue')
axs[1, 2].plot(xn,data1[b:tot,3],linestyle='dashed',color='royalblue')
axs[1, 2].plot(xn,data2[b:tot,3],color='royalblue')
axs[1, 3].plot(xn,data1[b:tot,4],linestyle='dashed',color='royalblue')
axs[1, 3].plot(xn,data2[b:tot,4],color='royalblue')
axs[2, 2].plot(xn,data1[b:tot,5],linestyle='dashed',color='royalblue')
axs[2, 2].plot(xn,data1[b:tot,0],linestyle='dashed',color='red')
axs[2, 2].plot(xn,data2[b:tot,5],color='royalblue')
axs[2, 2].plot(xn,data2[b:tot,0],color='red')
axs[2, 3].plot(xn,data1[b:tot,6],linestyle='dashed',color='royalblue')
axs[2, 3].plot(xn,data2[b:tot,6],color='royalblue')
axs[3, 2].plot(xn,data1[b:tot,7],linestyle='dashed',color='royalblue')
axs[3, 2].plot(xn,data2[b:tot,7],color='royalblue')
axs[3, 3].plot(xn,data1[b:tot,8],linestyle='dashed',color='royalblue')
axs[3, 3].plot(xn,data2[b:tot,8],color='royalblue')
axs[4, 2].plot(xn,data1[b:tot,9],linestyle='dashed',color='royalblue')
axs[4, 2].plot(xn,data2[b:tot,9],color='royalblue')
axs[4, 3].plot(xn,data1[b:tot,10],linestyle='dashed',color='royalblue')
axs[4, 3].plot(xn,data2[b:tot,10],color='royalblue')


ll = 0.7
ul = 6

axs[0,0].set_xlim([ll, ul])
axs[0,1].set_xlim([ll, ul])
axs[1,0].set_xlim([ll, ul])
axs[1,1].set_xlim([ll, ul])
axs[2,0].set_xlim([ll, ul])
axs[2,1].set_xlim([ll, ul])
axs[3,0].set_xlim([ll, ul])
axs[3,1].set_xlim([ll, ul])
axs[4,0].set_xlim([ll, ul])
axs[4,1].set_xlim([ll, ul])

axs[0,2].set_xlim([ll, ul])
axs[0,3].set_xlim([ll, ul])
axs[1,2].set_xlim([ll, ul])
axs[1,3].set_xlim([ll, ul])
axs[2,2].set_xlim([ll, ul])
axs[2,3].set_xlim([ll, ul])
axs[3,2].set_xlim([ll, ul])
axs[3,3].set_xlim([ll, ul])
axs[4,2].set_xlim([ll, ul])
axs[4,3].set_xlim([ll, ul])

axs[0, 0].set_title('R1.0')
axs[0, 1].set_title('R1.1')
axs[1, 0].set_title('R1.2')
axs[1, 1].set_title('R1.3')
axs[2, 0].set_title('TD1.4 and R1.4')
axs[2, 1].set_title('R1.5')
axs[3, 0].set_title('R1.6')
axs[3, 1].set_title('R1.7')
axs[4, 0].set_title('R1.8')
axs[4, 1].set_title('R1.9')
axs[0, 2].set_title('R1.0')
axs[0, 3].set_title('R1.1')
axs[1, 2].set_title('R1.2')
axs[1, 3].set_title('R1.3')
axs[2, 2].set_title('TD1.4 and R1.4')
axs[2, 3].set_title('R1.5')
axs[3, 2].set_title('R1.6')
axs[3, 3].set_title('R1.7')
axs[4, 2].set_title('R1.8')
axs[4, 3].set_title('R1.9')

line = plt.Line2D((.5,.5),(0,.95), color="k", linewidth=2)
fig.add_artist(line)
fig.suptitle(r'Corrleations between radii and pressure at $\rho / \rho_0$', fontsize=16)
plt.tight_layout()
plt.savefig("corr_stiff_soft_XEFT_dens.png",transparent=False,facecolor='white')

# %%
# Plot all
import numpy as np
import matplotlib.pyplot as plt
data1 = np.loadtxt("CORRMATRIX_soft_astro.txt")
data1 = np.transpose(data1)
data2 = np.loadtxt("CORRMATRIX_stiff_astro.txt")
data2 = np.transpose(data2)

data3 = np.loadtxt("CORRMATRIX_soft_XEFT.txt")
data3 = np.transpose(data3)
data4 = np.loadtxt("CORRMATRIX_stiff_XEFT.txt")
data4 = np.transpose(data4)

b = 94
n=48
tot=b+n
xb = np.linspace(0.7,10.0,b)
xn = np.linspace(0.3,5.0,n)

fig, axs = plt.subplots(5, 4,figsize=(20,15))
axs[0, 0].plot(xb,data1[0:b,1],linestyle='dashed',color='royalblue')
axs[0, 0].plot(xb,data2[0:b,1],color='royalblue')
axs[0, 1].plot(xb,data1[0:b,2],linestyle='dashed',color='royalblue')
axs[0, 1].plot(xb,data2[0:b,2],color='royalblue')
axs[1, 0].plot(xb,data1[0:b,3],linestyle='dashed',color='royalblue')
axs[1, 0].plot(xb,data2[0:b,3],color='royalblue')
axs[1, 1].plot(xb,data1[0:b,4],linestyle='dashed',color='royalblue')
axs[1, 1].plot(xb,data2[0:b,4],color='royalblue')
axs[2, 0].plot(xb,data1[0:b,5],linestyle='dashed',color='royalblue')
axs[2, 0].plot(xb,data1[0:b,0],linestyle='dashed',color='lightsteelblue')
axs[2, 0].plot(xb,data2[0:b,5],color='royalblue')
axs[2, 0].plot(xb,data2[0:b,0],color='lightsteelblue')
axs[2, 1].plot(xb,data1[0:b,6],linestyle='dashed',color='royalblue')
axs[2, 1].plot(xb,data2[0:b,6],color='royalblue')
axs[3, 0].plot(xb,data1[0:b,7],linestyle='dashed',color='royalblue')
axs[3, 0].plot(xb,data2[0:b,7],color='royalblue')
axs[3, 1].plot(xb,data1[0:b,8],linestyle='dashed',color='royalblue')
axs[3, 1].plot(xb,data2[0:b,8],color='royalblue')
axs[4, 0].plot(xb,data1[0:b,9],linestyle='dashed',color='royalblue')
axs[4, 0].plot(xb,data2[0:b,9],color='royalblue')
axs[4, 1].plot(xb,data1[0:b,10],linestyle='dashed',color='royalblue')
axs[4, 1].plot(xb,data2[0:b,10],color='royalblue')

axs[0, 0].plot(xb,data3[0:b,1],linestyle='dashed',color='red')
axs[0, 0].plot(xb,data4[0:b,1],color='red')
axs[0, 1].plot(xb,data3[0:b,2],linestyle='dashed',color='red')
axs[0, 1].plot(xb,data4[0:b,2],color='red')
axs[1, 0].plot(xb,data3[0:b,3],linestyle='dashed',color='red')
axs[1, 0].plot(xb,data4[0:b,3],color='red')
axs[1, 1].plot(xb,data3[0:b,4],linestyle='dashed',color='red')
axs[1, 1].plot(xb,data4[0:b,4],color='red')
axs[2, 0].plot(xb,data3[0:b,5],linestyle='dashed',color='red')
axs[2, 0].plot(xb,data3[0:b,0],linestyle='dashed',color='lightcoral')
axs[2, 0].plot(xb,data4[0:b,5],color='red')
axs[2, 0].plot(xb,data4[0:b,0],color='lightcoral')
axs[2, 1].plot(xb,data3[0:b,6],linestyle='dashed',color='red')
axs[2, 1].plot(xb,data4[0:b,6],color='red')
axs[3, 0].plot(xb,data3[0:b,7],linestyle='dashed',color='red')
axs[3, 0].plot(xb,data4[0:b,7],color='red')
axs[3, 1].plot(xb,data3[0:b,8],linestyle='dashed',color='red')
axs[3, 1].plot(xb,data4[0:b,8],color='red')
axs[4, 0].plot(xb,data3[0:b,9],linestyle='dashed',color='red')
axs[4, 0].plot(xb,data4[0:b,9],color='red')
axs[4, 1].plot(xb,data3[0:b,10],linestyle='dashed',color='red')
axs[4, 1].plot(xb,data4[0:b,10],color='red')

axs[0, 2].plot(xn,data1[b:tot,1],linestyle='dashed',color='royalblue')
axs[0, 2].plot(xn,data2[b:tot,1],color='royalblue')
axs[0, 3].plot(xn,data1[b:tot,2],linestyle='dashed',color='royalblue')
axs[0, 3].plot(xn,data2[b:tot,2],color='royalblue')
axs[1, 2].plot(xn,data1[b:tot,3],linestyle='dashed',color='royalblue')
axs[1, 2].plot(xn,data2[b:tot,3],color='royalblue')
axs[1, 3].plot(xn,data1[b:tot,4],linestyle='dashed',color='royalblue')
axs[1, 3].plot(xn,data2[b:tot,4],color='royalblue')
axs[2, 2].plot(xn,data1[b:tot,5],linestyle='dashed',color='royalblue')
axs[2, 2].plot(xn,data1[b:tot,0],linestyle='dashed',color='lightsteelblue')
axs[2, 2].plot(xn,data2[b:tot,5],color='royalblue')
axs[2, 2].plot(xn,data2[b:tot,0],color='lightsteelblue')
axs[2, 3].plot(xn,data1[b:tot,6],linestyle='dashed',color='royalblue')
axs[2, 3].plot(xn,data2[b:tot,6],color='royalblue')
axs[3, 2].plot(xn,data1[b:tot,7],linestyle='dashed',color='royalblue')
axs[3, 2].plot(xn,data2[b:tot,7],color='royalblue')
axs[3, 3].plot(xn,data1[b:tot,8],linestyle='dashed',color='royalblue')
axs[3, 3].plot(xn,data2[b:tot,8],color='royalblue')
axs[4, 2].plot(xn,data1[b:tot,9],linestyle='dashed',color='royalblue')
axs[4, 2].plot(xn,data2[b:tot,9],color='royalblue')
axs[4, 3].plot(xn,data1[b:tot,10],linestyle='dashed',color='royalblue')
axs[4, 3].plot(xn,data2[b:tot,10],color='royalblue')

axs[0, 2].plot(xn,data3[b:tot,1],linestyle='dashed',color='red')
axs[0, 2].plot(xn,data4[b:tot,1],color='red')
axs[0, 3].plot(xn,data3[b:tot,2],linestyle='dashed',color='red')
axs[0, 3].plot(xn,data4[b:tot,2],color='red')
axs[1, 2].plot(xn,data3[b:tot,3],linestyle='dashed',color='red')
axs[1, 2].plot(xn,data4[b:tot,3],color='red')
axs[1, 3].plot(xn,data3[b:tot,4],linestyle='dashed',color='red')
axs[1, 3].plot(xn,data4[b:tot,4],color='red')
axs[2, 2].plot(xn,data3[b:tot,5],linestyle='dashed',color='red')
axs[2, 2].plot(xn,data3[b:tot,0],linestyle='dashed',color='lightcoral')
axs[2, 2].plot(xn,data4[b:tot,5],color='red')
axs[2, 2].plot(xn,data4[b:tot,0],color='lightcoral')
axs[2, 3].plot(xn,data3[b:tot,6],linestyle='dashed',color='red')
axs[2, 3].plot(xn,data4[b:tot,6],color='red')
axs[3, 2].plot(xn,data3[b:tot,7],linestyle='dashed',color='red')
axs[3, 2].plot(xn,data4[b:tot,7],color='red')
axs[3, 3].plot(xn,data3[b:tot,8],linestyle='dashed',color='red')
axs[3, 3].plot(xn,data4[b:tot,8],color='red')
axs[4, 2].plot(xn,data3[b:tot,9],linestyle='dashed',color='red')
axs[4, 2].plot(xn,data4[b:tot,9],color='red')
axs[4, 3].plot(xn,data3[b:tot,10],linestyle='dashed',color='red')
axs[4, 3].plot(xn,data4[b:tot,10],color='red')

axs[0,0].set_xlim([0.7, 4])
axs[0,1].set_xlim([0.7, 4])
axs[1,0].set_xlim([0.7, 4])
axs[1,1].set_xlim([0.7, 4])
axs[2,0].set_xlim([0.7, 4])
axs[2,1].set_xlim([0.7, 4])
axs[3,0].set_xlim([0.7, 4])
axs[3,1].set_xlim([0.7, 4])
axs[4,0].set_xlim([0.7, 4])
axs[4,1].set_xlim([0.7, 4])

ll = 0.5
ul = 6
axs[0,2].set_xlim([ll, ul])
axs[0,3].set_xlim([ll, ul])
axs[1,2].set_xlim([ll, ul])
axs[1,3].set_xlim([ll, ul])
axs[2,2].set_xlim([ll, ul])
axs[2,3].set_xlim([ll, ul])
axs[3,2].set_xlim([ll, ul])
axs[3,3].set_xlim([ll, ul])
axs[4,2].set_xlim([ll, ul])
axs[4,3].set_xlim([ll, ul])

axs[0, 0].set_title('R1.0')
axs[0, 1].set_title('R1.1')
axs[1, 0].set_title('R1.2')
axs[1, 1].set_title('R1.3')
axs[2, 0].set_title('TD1.4 and R1.4')
axs[2, 1].set_title('R1.5')
axs[3, 0].set_title('R1.6')
axs[3, 1].set_title('R1.7')
axs[4, 0].set_title('R1.8')
axs[4, 1].set_title('R1.9')
axs[0, 2].set_title('R1.0')
axs[0, 3].set_title('R1.1')
axs[1, 2].set_title('R1.2')
axs[1, 3].set_title('R1.3')
axs[2, 2].set_title('TD1.4 and R1.4')
axs[2, 3].set_title('R1.5')
axs[3, 2].set_title('R1.6')
axs[3, 3].set_title('R1.7')
axs[4, 2].set_title('R1.8')
axs[4, 3].set_title('R1.9')

plt.tight_layout()
plt.savefig("corr_stiff_soft_all.png",transparent=False,facecolor='white')

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt("CORR_BEM_en.txt")
data = np.transpose(data)

fig, axs = plt.subplots(5, 4,figsize=(20,15))
axs[0, 0].plot(xb,data[0:b,1])
axs[0, 1].plot(xb,data[0:b,2])
axs[1, 0].plot(xb,data[0:b,3])
axs[1, 1].plot(xb,data[0:b,4])
axs[2, 0].plot(xb,data[0:b,5],xb,data[0:b,0])
axs[2, 1].plot(xb,data[0:b,6])
axs[3, 0].plot(xb,data[0:b,7])
axs[3, 1].plot(xb,data[0:b,8])
axs[4, 0].plot(xb,data[0:b,9])
axs[4, 1].plot(xb,data[0:b,10])
axs[0, 2].plot(xn,data[b:tot,1])
axs[0, 3].plot(xn,data[b:tot,2])
axs[1, 2].plot(xn,data[b:tot,3])
axs[1, 3].plot(xn,data[b:tot,4])
axs[2, 2].plot(xn,data[b:tot,5],xn,data[b:tot,0])
axs[2, 3].plot(xn,data[b:tot,6])
axs[3, 2].plot(xn,data[b:tot,7])
axs[3, 3].plot(xn,data[b:tot,8])
axs[4, 2].plot(xn,data[b:tot,9])
axs[4, 3].plot(xn,data[b:tot,10])

axs[0,0].set_xlim([0.7, 4])
axs[0,1].set_xlim([0.7, 4])
axs[1,0].set_xlim([0.7, 4])
axs[1,1].set_xlim([0.7, 4])
axs[2,0].set_xlim([0.7, 4])
axs[2,1].set_xlim([0.7, 4])
axs[3,0].set_xlim([0.7, 4])
axs[3,1].set_xlim([0.7, 4])
axs[4,0].set_xlim([0.7, 4])
axs[4,1].set_xlim([0.7, 4])

# %%
import numpy as np
# Define the matrix
matrix = np.array([
    [3.520788519767681602e+06, -2.032395901923854835e+06, -2.156442390303633583e+05, -1.335893759477658605e+05, -2.977032505005992134e+05, 1.230035311963580316e+05, -2.458721004978353449e+04],
    [-2.032395901923855534e+06, 2.893733953336347360e+06, 1.337347512873199012e+05, 1.710015317840318312e+05, 1.452816787220708502e+05, -4.180548613393308915e+04, 3.402539672500140296e+04],
    [-2.156442390303634165e+05, 1.337347512873199594e+05, 4.628849143940719659e+04, 8.628150360928882947e+03, 6.099302644748061539e+03, -1.823202635404351668e+03, 2.428615781656744730e+03],
    [-1.335893759477658605e+05, 1.710015317840318312e+05, 8.628150360928879309e+03, 1.984496885421955812e+04, 8.545203801211691825e+03, -3.680891658362813359e+03, 2.417957814305741522e+03],
    [-2.977032505005992134e+05, 1.452816787220706465e+05, 6.099302644748065177e+03, 8.545203801211691825e+03, 4.527931292396966455e+04, -2.005822492317762953e+04, 2.859408916994232186e+03],
    [1.230035311963579734e+05, -4.180548613393300184e+04, -1.823202635404352577e+03, -3.680891658362813814e+03, -2.005822492317762226e+04, 1.086283086710552016e+04, -1.217236704300192969e+03],
    [-2.458721004978358178e+04, 3.402539672500143206e+04, 2.428615781656746094e+03, 2.417957814305744250e+03, 2.859408916994236733e+03, -1.217236704300194106e+03, 2.342702697092955532e+03]
])

# Compute the inverse of the matrix
inverse_matrix = np.linalg.inv(matrix)

print("Inverse Matrix:")
print(inverse_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # Define the matrix
# ----> 2 matrix = np.array([
#       3     [3.520788519767681602e+06, -2.032395901923854835e+06, -2.156442390303633583e+05, -1.335893759477658605e+05, -2.977032505005992134e+05, 1.230035311963580316e+05, -2.458721004978353449e+04],
#       4     [-2.032395901923855534e+06, 2.893733953336347360e+06, 1.337347512873199012e+05, 1.710015317840318312e+05, 1.452816787220708502e+05, -4.180548613393308915e+04, 3.402539672500140296e+04],
#       5     [-2.156442390303634165e+05, 1.337347512873199594e+05, 4.628849143940719659e+04, 8.628150360928882947e+03, 6.099302644748061539e+03, -1.823202635404351668e+03, 2.428615781656744730e+03],
# ...
